# %% [markdown]
# Visualizzazione grafica dei risultati ottenuti con sentiment analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
source = "../doc/sentiment_analysis_all.csv"
df = pd.read_csv(source)

# %%
#Conteggio dei tweet 

#positive, negative, neutral
sentiment = df['sentiment'].value_counts()
n_positive = sentiment.get('positive', 0)
n_negative = sentiment.get('negative', 0)   
n_neutral = sentiment.get('neutral', 0)
print("Number of positive examples: ",n_positive)
print("Number of negative examples: ",n_negative)
print("Number of neutral examples: ",n_neutral)
tot = n_positive + n_negative + n_neutral
print("Totale: ",tot)

print("------------------------------------")

# joy, anger, love, sadness, fear, surprise, optimism, pessimism, anticipation, disgust, trust
emotion = df['emotion'].value_counts()

n_joy = emotion.get('joy', 0)
n_anger = emotion.get('anger', 0)
n_sadness = emotion.get('sadness', 0)
n_fear = emotion.get('fear', 0)
n_disgust = emotion.get('disgust', 0)
n_love = emotion.get('love', 0)
n_surprise = emotion.get('surprise', 0)
n_optimism = emotion.get('optimism', 0)
n_pessimism = emotion.get('pessimism', 0)
n_anticipation = emotion.get('anticipation', 0)
n_trust = emotion.get('trust', 0)
print("Number of joy examples: ",n_joy)
print("Number of anger examples: ",n_anger)
print("Number of love examples: ",n_love)
print("Number of sadness examples: ",n_sadness)
print("Number of fear examples: ",n_fear)
print("Number of disgust examples: ",n_disgust)
print("Number of surprise examples: ",n_surprise)
print("Number of optimism examples: ",n_optimism)
print("Number of pessimism examples: ",n_pessimism)
print("Number of anticipation examples: ",n_anticipation)
print("Number of trust examples: ",n_trust)
tot = n_joy + n_anger + n_love + n_sadness + n_fear + n_disgust + n_surprise + n_optimism + n_pessimism + n_anticipation + n_trust
print("Totale: ",tot)

#hate, not-hate
hate = df['hate'].value_counts()
n_hate = hate.get('hate', 0)
n_not_hate = hate.get('not-hate', 0)
print("Number of hate examples: ",n_hate)
print("Number of not-hate examples: ",n_not_hate)
tot = n_hate + n_not_hate
print("Totale: ",tot)

#offensive, non-offensive
offensive = df['offensive'].value_counts()
n_offensive = offensive.get('offensive', 0)
n_non_offensive = offensive.get('non-offensive', 0)
print("Number of offensive examples: ",n_offensive)
print("Number of non-offensive examples: ",n_non_offensive)
tot = n_offensive + n_non_offensive
print("Totale: ",tot)
# Out:
# Number of positive examples:  21071
# Number of negative examples:  23108
# Number of neutral examples:  25821
# Totale:  70000
# ------------------------------------
# Number of joy examples:  11063
# Number of anger examples:  18909
# Number of love examples:  3
# Number of sadness examples:  1992
# Number of fear examples:  3666
# Number of disgust examples:  6397
# Number of surprise examples:  59
# Number of optimism examples:  14297
# Number of pessimism examples:  0
# Number of anticipation examples:  13614
# Number of trust examples:  0
# Totale:  70000
# Number of hate examples:  2400
# Number of not-hate examples:  67600
# Totale:  70000
# Number of offensive examples:  4315
# Number of non-offensive examples:  65685
# Totale:  70000

# %%
#Plotting
counts = [n_neutral, n_negative, n_positive]
colors = ['grey', 'lightcoral', 'lightgreen']
fig = plt.figure(figsize=(10,6))
bars = plt.bar(sentiment.index, sentiment.values, color=colors)
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment', fontweight='bold')
plt.ylabel('Number of tweets', fontweight='bold')
for bar, count in zip(bars, counts):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1, str(count), ha='center', va='bottom', color='black', fontweight='bold')

plt.show()
fig.savefig('./result sentimental analysis/grafici/sentimentXtweet.png', dpi=300, bbox_inches='tight')

# %%
#plotting emotion

# Create a DataFrame with all possible emotions and merge with 'emotion' to fill missing values with zeros
all_emotions = pd.Series(index=['joy', 'anger', 'fear', 'trust', 'surprise', 'disgust', 'sadness', 'pessimism'], dtype=int)
emotion = all_emotions.combine_first(emotion).fillna(0).astype(int)
emotion = emotion.sort_values(ascending=False)

colors = plt.cm.tab10(np.linspace(0, 1, len(emotion)))
fig = plt.figure(figsize=(15, 6))
bars = plt.bar(emotion.index, emotion.values, color=colors)

plt.title('Emotion Analysis')
plt.xlabel('Emotion', fontweight='bold')
plt.ylabel('Number of tweets', fontweight='bold')

# Add exact numbers on top of the bars
for bar, count in zip(bars, emotion.values):
    plt.text(bar.get_x() + bar.get_width() / 2 , bar.get_height() + 0.1, str(count), ha='center', va='bottom', color='black', fontweight='bold')

plt.show()
fig.savefig('./result sentimental analysis/grafici/emotionXtweet.png', dpi=300, bbox_inches='tight')

# %%
#Plotting hate
colors = ['lightgreen', 'red']
fig = plt.figure(figsize=(10,6))
bars = plt.bar(hate.index, hate.values, color=colors)
plt.title('Hate Analysis')
plt.xlabel('Hate', fontweight='bold')
plt.ylabel('Number of tweets', fontweight='bold')
#count the hate example and plot the number on top of the bar
for bar, count in zip(bars, hate.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1, str(count), ha='center', va='bottom', color='black', fontweight='bold')

plt.show()
fig.savefig('./result sentimental analysis/grafici/hateXtweet.png', dpi=300, bbox_inches='tight')

# %%
#plotting offensive
colors = ['lightblue', 'purple']
fig = plt.figure(figsize=(10,6))
bars = plt.bar(offensive.index, offensive.values, color=colors)
plt.title('Offensive Analysis')
plt.xlabel('Offensive', fontweight='bold')
plt.ylabel('Number of tweets', fontweight='bold')
#count the offensive example and plot the number on top of the bar
for bar, count in zip(bars, offensive.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1, str(count), ha='center', va='bottom', color='black', fontweight='bold')

plt.show()
fig.savefig('./result sentimental analysis/grafici/offensiveXtweet.png', dpi=300, bbox_inches='tight')

# %%
#Plotting sentiment for each emotion
# Get unique sentiments and emotions
sentiments = df['sentiment'].unique()
emotions = df['emotion'].unique()

# Define the desired order for sentiments
sentiment_order = ['neutral', 'negative', 'positive']

# Create a grid of subplots
num_rows = 3
num_cols = 3
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(10, 13))
fig.suptitle('Sentiment Analysis for each emotion', fontsize=14)

# Plot for each emotion
for i, emotion in enumerate(emotions):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]

    # Count the number of each sentiment for the current emotion
    counts = df[df['emotion'] == emotion]['sentiment'].value_counts()

    # Plot the bar chart with specified order for x-axis ticks
    bars = ax.bar(sentiment_order, [counts.get(sentiment, 0) for sentiment in sentiment_order],
                  color=['grey', 'lightcoral', 'lightgreen'])
    ax.set_title(f'Emotion: {emotion}')
    ax.set_xlabel('Sentiment', fontweight='bold')
    ax.set_ylabel('Number of tweets', fontweight='bold')

    # Add numbers on top of the bars
    for bar, count in zip(bars, [counts.get(sentiment, 0) for sentiment in sentiment_order]):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005, str(count),
                ha='center', va='bottom', color='black', fontweight='bold')

plt.tight_layout()
plt.show()
fig.savefig('./result sentimental analysis/grafici/sentimentXemotion.png', dpi=300, bbox_inches='tight')

# %%
#emotion analysis for each sentiment
#Plotting sentiment for each emotion
# Get unique sentiments and emotions
sentiments = df['sentiment'].unique()
emotions = df['emotion'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(emotions)))

# Define the desired order for sentiments
emotion_order = []
for emotion in emotions:
    emotion_order.append(emotion)

# Create a grid of subplots
num_rows = 1
num_cols = 3
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 5))
fig.suptitle('Emotions for each sentiment', fontsize=14)

# Plot for each emotion
for i, sentiment in enumerate(sentiments):
    ax = axes[i]

    # Count the number of each emotion for the current sentiment
    counts = df[df['sentiment'] == sentiment]['emotion'].value_counts()

    # Plot the bar chart with specified order for x-axis ticks
    bars = ax.bar(emotion_order, [counts.get(emotion, 0) for emotion in emotion_order],
                  color=colors)
    ax.set_title(f'Sentiment: {sentiment}')
    ax.set_xlabel('Emotion', fontweight='bold')
    ax.set_ylabel('Number of tweets', fontweight='bold')
    ax.set_xticklabels(emotion_order, rotation=45, ha='right')

    # Add numbers on top of the bars
    for bar, count in zip(bars, [counts.get(emotion, 0) for emotion in emotion_order]):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005, str(count),
                ha='center', va='bottom', color='black', fontweight='bold')

plt.tight_layout()
plt.show()
fig.savefig('./result sentimental analysis/grafici/emotionXsentiment.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_20810/3738785035.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/3738785035.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/3738785035.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')

# %%
#plotting sentiment for each topic

# Get unique sentiments and topics
sentiments = df['sentiment'].unique()
topics = df['first_topic_name'].unique()

# Define the desired order for sentiments
sentiment_order = ['neutral', 'negative', 'positive']

# Create a grid of subplots
num_rows = 2
num_cols = 4
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 10))
fig.suptitle('Sentiment Analysis for each topic', fontsize=14)

# Plot for each topic
for i, topic in enumerate(topics):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]

    # Count the number of each sentiment for the current topic
    counts = df[df['first_topic_name'] == topic]['sentiment'].value_counts()

    # Plot the bar chart with specified order for x-axis ticks
    bars = ax.bar(sentiment_order, [counts.get(sentiment, 0) for sentiment in sentiment_order],
                  color=['grey', 'lightcoral', 'lightgreen'])
    ax.set_title(f'topic: {topic}')
    ax.set_xlabel('Sentiment', fontweight='bold')
    ax.set_ylabel('Number of tweets', fontweight='bold')

    # Add numbers on top of the bars
    for bar, count in zip(bars, [counts.get(sentiment, 0) for sentiment in sentiment_order]):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005, str(count),
                ha='center', va='bottom', color='black', fontweight='bold')

plt.tight_layout()
plt.show()
fig.savefig('./result sentimental analysis/grafici/sentimentXtopic.png', dpi=300, bbox_inches='tight')

# %%
#plotting emotions for each topic

# Get unique emotions and topics
emotions = df['emotion'].unique()
topics = df['first_topic_name'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(emotions)))

# Define the desired order for emotions
emotion_order = []
for i, emotion in enumerate(emotions):
    emotion_order.append(emotion)

# Create a grid of subplots
num_rows = 3
num_cols = 3
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 15))
fig.suptitle('Emotion Analysis for each topic', fontsize=14)

# Plot for each topic
for i, topic in enumerate(topics):
    
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]

    # Count the number of each emotion for the current topic
    counts = df[df['first_topic_name'] == topic]['emotion'].value_counts()

    # Plot the bar chart with specified order for x-axis ticks
    bars = ax.bar(emotion_order, [counts.get(emotion, 0) for emotion in emotion_order],
                  color=colors)
    ax.set_title(f'Topic: {topic}')
    ax.set_xlabel('Emotion', fontweight='bold')
    ax.set_ylabel('Number of tweets', fontweight='bold')
    # Rotate x-axis labels at 45 degrees
    ax.set_xticklabels(emotion_order, rotation=45, ha='right')

    # Add numbers on top of the bars
    for bar, count in zip(bars, [counts.get(emotion, 0) for emotion in emotion_order]):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005, str(count),
                ha='center', va='bottom', color='black', fontweight='bold')
        
# Remove the last subplot
fig.delaxes(axes.flatten()[-1])

plt.tight_layout()
plt.show()
fig.savefig('./result sentimental analysis/grafici/emotionXtopic.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_20810/1156481455.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/1156481455.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/1156481455.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/1156481455.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/1156481455.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/1156481455.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/1156481455.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')
# /tmp/ipykernel_20810/1156481455.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(emotion_order, rotation=45, ha='right')

# %%
# Plotting hate for each topic
# Get unique topics
topics = df['first_topic_name'].unique()

# Create a grid of subplots
num_rows = 3
num_cols = 3
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 15))
fig.suptitle('Hate Analysis for each topic', fontsize=14)

# Plot for each topic
for i, topic in enumerate(topics):
    
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]

    # Count the number of hate for the current topic
    counts = df[df['first_topic_name'] == topic]['hate'].value_counts()

    # Plot the bar chart with specified order for x-axis ticks
    bars = ax.bar(counts.index, counts.values, color=['lightgreen', 'red'])
    ax.set_title(f'Topic: {topic}')
    ax.set_xlabel('Hate', fontweight='bold')
    ax.set_ylabel('Number of tweets', fontweight='bold')

    # Add numbers on top of the bars
    for bar, count in zip(bars, counts.values):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1, str(count),
                ha='center', va='bottom', color='black', fontweight='bold')
# Remove the last subplot
fig.delaxes(axes.flatten()[-1])

plt.tight_layout()
plt.show()
fig.savefig('./result sentimental analysis/grafici/hateXtopic.png', dpi=300, bbox_inches='tight')

# %%
#plot offensive for each topic
# Get unique topics
topics = df['first_topic_name'].unique()

# Create a grid of subplots
num_rows = 3
num_cols = 3
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 15))
fig.suptitle('Offensive Analysis for each topic', fontsize=14)

# Plot for each topic
for i, topic in enumerate(topics):
    
    row = i // num_cols
    col = i % num_cols
    ax = axes[row, col]

    # Count the number of offensive for the current topic
    counts = df[df['first_topic_name'] == topic]['offensive'].value_counts()

    # Plot the bar chart with specified order for x-axis ticks
    bars = ax.bar(counts.index, counts.values, color=['lightblue', 'purple'])
    ax.set_title(f'Topic: {topic}')
    ax.set_xlabel('Offensive', fontweight='bold')
    ax.set_ylabel('Number of tweets', fontweight='bold')

    # Add numbers on top of the bars
    for bar, count in zip(bars, counts.values):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1, str(count),
                ha='center', va='bottom', color='black', fontweight='bold')
# Remove the last subplot
fig.delaxes(axes.flatten()[-1])

plt.tight_layout()
plt.show()
fig.savefig('./result sentimental analysis/grafici/offensiveXtopic.png', dpi=300, bbox_inches='tight')

# %%
#Show some random tweets for each emotion
emotions = df['emotion'].unique()

for emotion in emotions:
    print(f'Emotion: {emotion}')
    
    # Sample 5 tweets for the current emotion
    sampled_tweets = df[df['emotion'] == emotion]
    if len(sampled_tweets) > 5:
        sampled_tweets = sampled_tweets.sample(10)
    
    
    # Iterate over the rows using iterrows()
    for index, tweet in sampled_tweets.iterrows():
        print(f"{index}) topic: {tweet['first_topic_name']}, sentiment: {tweet['sentiment']}, prob_emotion: {tweet['emotion_prob']}, {tweet['text']}")
    
    print('\n')
# Out:
# Emotion: anger
# 8363) topic: Election/debate, sentiment: negative, prob_emotion: 0.715911865234375, Two brown people #Republicans will never vote for! Nimrata Haley and Vivek Ramaswamy. Also, Uncle Tim Scott! White supremacy is the GOP brand at the moment, and these folks are just a little too tan. #GOPDebate
# 18450) topic: American/economics/health, sentiment: negative, prob_emotion: 0.5455663800239563, NEWS: A new survey found that 1 in 5 mothers endured some kind of mistreatment or discrimination by their healthcare providers during maternity care. That's unacceptable. ALL moms should be heard and provided the best care. https://t.co/NyX5QTZvEm
# 9629) topic: Infrastructure/job/energy, sentiment: positive, prob_emotion: 0.5545342564582825, RT @Starbucks partners should be respected, protected and paid! Today, @SBWorkersUnited &amp; customers are out in force demanding Starbucks quit union-busting &amp; come to the bargaining table! #SolidaritySeason https://t.co/yLx9j7Lqhn
# 5548) topic: War, sentiment: negative, prob_emotion: 0.7040159702301025, The media despised by the American people, and for damn good reasons https://t.co/ETvAlkxJi7
# 618) topic: Republicans vs democrats, sentiment: neutral, prob_emotion: 0.6190458536148071, "The bottom line is that all of these rocks have been directed at either Mr. Trump or Mr. DeSantis. No one is wasting any time, effort or ammunition on Ms. Haley, Mr. Scott or any of the other munchkins in the race," writes @mikemckenna3. https://t.co/xAF5VCu6VD
# 15280) topic: American/economics/health, sentiment: neutral, prob_emotion: 0.4763311147689819, Last month, I asked constituents to share their experiences with junk fees, which are hidden or surprise charges often added right at the end of transactions. (1/4)
# 2081) topic: Republicans vs democrats, sentiment: neutral, prob_emotion: 0.4153752028942108, Want a timeline of the Bidens’ influence peddling schemes? Read this. https://t.co/HjPZfVBINo
# 10443) topic: Infrastructure/job/energy, sentiment: negative, prob_emotion: 0.8835479021072388, Calling all decent #republicans that dare want to work with #democrats toward a stronger or better country, raise your damn hand! 🖐
# 10160) topic: Infrastructure/job/energy, sentiment: negative, prob_emotion: 0.7409976720809937, Taxpayers helped keep the airline industry – and its employees – afloat during the pandemic. So I know you're frustrated with the service you're getting from them. Today, I'm announcing two critical steps to protect air passengers. It's time for you to get a better deal.
# 67191) topic: American/economics/health, sentiment: positive, prob_emotion: 0.8262224197387695, Last year, President Biden signed the most significant gun safety legislation in 30 years. Today, the admin moved to close the "gun show loophole" &amp; expand common-sense background checks. President Biden is standing up to the gun lobby and saving lives. https://t.co/A46c51siQP
# 65373) topic: American/economics/health, sentiment: positive, prob_emotion: 0.645572304725647, RT @While MAGA Republicans in Congress prioritize their MAGA agenda, the Biden-Harris admin is fighting for the American people by supporting bills like the For the People Act, Freedom to Vote Act and John R. Lewis Voting Rights Advancement Act to #DefendOurDemocracy!
# 58340) topic: Infrastructure/job/energy, sentiment: neutral, prob_emotion: 0.7646319270133972, Last week I signed legislation that tackles distracted driving, an issue that has caused pain and heartache for too many Michigan families. Let’s keep our eyes on the road and off our phones, and build a brighter, safer Michigan for everyone. https://t.co/dgcui00GyP
# 59933) topic: American/economics/health, sentiment: neutral, prob_emotion: 0.5353418588638306, RT @While MAGA Republicans prioritize tax breaks for billionaires and big corporations, I'm working to deliver investments in child care, job training, and public schools. We must advocate for the needs of everyday Nevadans. Nevada's working families deserve better. https://t.co/idWIrZRBLY
#
#
# Emotion: sadness
# 69613) topic: Election/debate, sentiment: negative, prob_emotion: 0.393095999956131, @LeaderMcConnell @ZelenskyyUa McConnell has a #mancrush on #Zelinsky too bad the #6160224test Senator from #Kentucky yields no power he has spent 50 years reshaping the country to control the #SupremeCourt and now the #Republicans party are characters from #AnimalFarm the book @BLANG1911 https://t.co/VWcqqHl6p7
# 68069) topic: Infrastructure/job/energy, sentiment: negative, prob_emotion: 0.3916524052619934, In 2021, Michigan's automotive assembly lines came to a halt because overseas manufacturers couldn’t produce semiconductor chips. That’s why I went to Taiwan – a major semiconductor chip hub in the world – to bring manufacturing back to Michigan so that never happens again.
# 68395) topic: Republicans vs democrats, sentiment: negative, prob_emotion: 0.5813267230987549, I don't know what's causing the spike in adolescent unhappiness, but it's whatever it is it's 1) relatively new) and 2) *not* affecting adults in the same way. So that narrows the range of possibilities. Almost certainly not a perpetual, very adult concern like "job security"!
# 68116) topic: Infrastructure/job/energy, sentiment: negative, prob_emotion: 0.8827188611030579, We are broken. As a society, as a people, as a species bringing our very home to the precipice of collapse, we are broken. We have the resources - natural and technological - to thrive. Yet we squander it all. 🧵 (1/14)
# 69524) topic: Border/community/family, sentiment: positive, prob_emotion: 0.4797621667385101, Our family wishes condolences to Suzanne, Jonathan and Josh on the loss of their husband and father, NJ legend Steve Kalafer. As a lifelong New Jerseyan, I never met a kinder or more generous person. Steve is not only an irreplaceable force for his family—he is the same for NJ.
# 69934) topic: Infrastructure/job/energy, sentiment: neutral, prob_emotion: 0.4834963679313659, President Joe Biden has an ambitious agenda when he sets off this week on an eight-day trip to the Indo-Pacific. But hanging over his travels is the debt crisis at home that threatens to spark an economic downturn. https://t.co/3n0EewP3je
# 69520) topic: Republicans vs democrats, sentiment: negative, prob_emotion: 0.754545271396637, Sadly, some #GOP cowards are hiding their heads in the sand concerning #Ukraine. When did #Republicans become doves and #Dems the hawks? #SupportUkraine. Ukraine Strikes the Headquarters of Russia’s Black Sea Fleet in Crimea https://t.co/41Y7s2Ga87
# 69437) topic: Abortion/rights/guns, sentiment: neutral, prob_emotion: 0.8795636892318726, Samuel Sandoval, one of the last remaining Navajo Code Talkers who transmitted messages in World War II using a code based on their native language, has died at 98. https://t.co/xFqQorWhiS
# 69791) topic: Border/community/family, sentiment: negative, prob_emotion: 0.9521259665489196, My heart breaks for the families torn apart, the lives uprooted. The costs of this war cannot be overstated.
# 69184) topic: Border/community/family, sentiment: negative, prob_emotion: 0.7914307713508606, 10 years ago, a gunman took the lives of 20 first graders and 6 educators at Sandy Hook Elementary. Sadly, the last year has shown gun violence continues to plague our nation. While we remember the lives lost that day, that can't be all we do.
#
#
# Emotion: surprise
# 69983) topic: Infrastructure/job/energy, sentiment: negative, prob_emotion: 0.3588089644908905, Always crazy to me that Japan's GDP has basically not grown for 30 years https://t.co/xj0fhN7xBg
# 69976) topic: Republicans vs democrats, sentiment: positive, prob_emotion: 0.4239176213741302, and in general, the difference between the material sized from boxes in trump's office v. the storage room is extremely striking when presented visually
# 69965) topic: Republicans vs democrats, sentiment: neutral, prob_emotion: 0.2389344424009323, The Fed's inflation target was not always 2% - for decades it was 3%. I've been surprised the Fed has not given themselves more flexibility to pivot from 2% to 3%
# 69960) topic: Election/debate, sentiment: negative, prob_emotion: 0.4611237347126007, I was genuinely shocked by this graph. I assumed early support for presidential candidates was often irrelevant—as it was for, say, Guiliani in 2008. Totally wrong. Early poll leaders at this point in the cycle "won the nomination more often than not in the modern primary era." https://t.co/Fwx0arKyAI
# 69943) topic: Republicans vs democrats, sentiment: neutral, prob_emotion: 0.3314639329910278, 1/2 NRSC tells NewsNation they fully stand by the ad. From NRSC Spox @AbboudMf “Elissa Slotkin acknowledged signing an NDA related to the Gotion project negotiations. It is bizarre, but not surprising, that she’s now trying to cover up her involvement in this sketchy deal…
# 69992) topic: Republicans vs democrats, sentiment: negative, prob_emotion: 0.4053546190261841, @tedcruz OMG. The President of the USA picking a fight with a Union WORKER. Can't make this up. Oh dear. Wow. Um, speechless. #Biden2024
# 69984) topic: Election/debate, sentiment: negative, prob_emotion: 0.2665455639362335, RT @NBC: Officials who work for DeSantis' administration — not his campaign — have texted lobbyists to solicit contributions for his presidential bid, a breach of norms that has raised ethical &amp; legal questions and left many in the state capital shocked https://t.co/rdeEBxYwzq
# 69958) topic: Abortion/rights/guns, sentiment: negative, prob_emotion: 0.3598111867904663, #USPolitics quite puzzles me. This is like Clive Palmer going to Canberra to vie for speaker of the house. #AusPol
# 69988) topic: Election/debate, sentiment: positive, prob_emotion: 0.354686975479126, JUST IN: Former President Donald Trump has allegedly purchased a Glock handgun in South Carolina. Amazing 🇺🇸 https://t.co/VusyrcFKlh
# 69989) topic: Republicans vs democrats, sentiment: negative, prob_emotion: 0.573535680770874, Prosecutors quietly drop five charges against Democrat megadonor Sam Bankman Fried. Shocker! https://t.co/X86ZCuL3jP
